# %% [markdown]
# # Step-1 : Business problem Understanding.
#
# * What is the relationship between each advertising channel(Tv,Radio,Newspaper) and sales.
#
# * Priviously, we explored is there a relationship between total advertising spend and sales? as well predicting the total sales for some value of total spend.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Step-2: Data Collection & Understanding the data

# %%
df=pd.read_csv("Advertising.csv")
df.head()
# Out:
#        TV  radio  newspaper  sales
# 0  230100  37800      69200  22100
# 1   44500  39300      45100  10400
# 2   17200  45900      69300   9300
# 3  151500  41300      58500  18500
# 4  180800  10800      58400  12900

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    int64
#  1   radio      200 non-null    int64
#  2   newspaper  200 non-null    int64
#  3   sales      200 non-null    int64
# dtypes: int64(4)
# memory usage: 6.4 KB

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %% [markdown]
# # step -3: Explority data analysis

# %%
df.describe()
# Out:
#                   TV         radio      newspaper         sales
# count     200.000000    200.000000     200.000000    200.000000
# mean   147042.500000  23264.000000   30554.000000  14022.500000
# std     85854.236315  14846.809176   21778.620839   5217.456566
# min       700.000000      0.000000     300.000000   1600.000000
# 25%     74375.000000   9975.000000   12750.000000  10375.000000
# 50%    149750.000000  22900.000000   25750.000000  12900.000000
# 75%    218825.000000  36525.000000   45100.000000  17400.000000
# max    296400.000000  49600.000000  114000.000000  27000.000000

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
# * The relation between y and x should high. the higher the value the stronger the correlation.
#
# * The relation between any two independent variables should be low.

# %% [raw]
# If the correlation any 2  independent variable is strong, then it is caalled colinearity problem

# %% [markdown]
# # Step- 3.2 : Data Cleaning
#
# # Step- 3.3 : Data Wragling
#
# # step- 3.4 : Train-Test Split

# %%
#x=df[["TV","radion","newspaper"]]
#y=df['sales']

# %%
x = df.drop(columns='sales')
y = df['sales']

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# # step -4 : Modelling

# %% [markdown]
# Multiple linear Regression - Linear Regression include multiple input features. This is done by least
#                               square method.
#
# y= B0+B1*X1+B2*X2+B3*X3
#
# Each x represents a different feature, and each feature has its own coefficient.
#
# * In this Case:
#
# Y=B0+B*TV+B2*Radio+B3*Newspaper

# %%
from sklearn.linear_model import LinearRegression
#import model

model=LinearRegression()  #save the model

model.fit(x_train,y_train) #Fit the data
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 2708.949092515906

# %%
model.coef_
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %% [markdown]
# # Prediction

# %%
train_predictions=model.predict(x_train)
train_predictions
# Out:
# array([17391.49783007, 15191.96152532, 11416.50701444, 11206.1047219 ,
#        16392.56164803,  6905.77777803, 21177.40605973,  6105.2857409 ,
#         9666.62606558, 11673.08586975,  9070.43769888,  6305.82198575,
#        14793.01209566, 17429.99511941, 16145.99956044, 16122.7390561 ,
#        14930.86289848, 19615.93142419, 13707.41553479, 21090.67507365,
#        13091.01877165, 13795.51693107,  8879.71635804, 16973.48947493,
#         8229.02448465, 15340.26922744, 13958.62675411, 23231.57580535,
#        12679.92503577, 23107.68546084,  6800.57243207, 18818.3225922 ,
#        23696.69553497, 18398.90878846, 16978.90644855, 16440.55305478,
#        12416.57918445, 11940.72527308, 16773.29180451, 14593.39970137,
#        13229.10726592,  7496.9160136 , 19301.21037991,  9331.05452496,
#        19360.37660286, 10164.63426617,  6943.6903896 , 16529.18217324,
#        13535.71009432, 14802.2585121 , 11139.48107306, 20856.32271739,
# ...

# %%
test_predictions=model.predict(x_test)
test_predictions
# Out:
# array([16565.39629743, 21188.22791624, 21551.0705832 , 10889.23815574,
#        22202.3198826 , 13355.568716  , 21196.9250184 ,  7350.28522531,
#        13275.47079102, 15124.4951134 ,  9014.43026128,  6525.42824565,
#        14302.05991495,  8970.26041785,  9456.79575868, 12004.54350551,
#         8915.49402837, 16156.19250901, 10295.82883289, 18724.73553098,
#        19768.21817698, 13774.69028127, 12496.38907537, 21535.01761723,
#         7608.60740674,  5611.98009509, 20917.5948287 , 11806.27664759,
#         9080.76636797,  8514.12011788, 12176.04890687,  9969.19389687,
#        21730.0895551 , 12777.70578385, 18101.1361964 , 20075.907957  ,
#        14262.0255609 , 20938.26534862, 10839.38826715,  4381.90607489,
#         9513.32405604, 12404.86323737, 10170.45434199,  8090.81363276,
#        13163.88427421,  5224.35520428,  9288.93832916, 14093.30719088,
#         8690.24496944, 11661.19762985, 15718.48431993, 11631.56862218,
# ...

# %% [markdown]
# # Step- 5 Evaluation metrics

# %%
# Out:
# 1574.5968305905444 1948.5372043446387

# %%
#Accuracy

train_r2=model.score(x_train,y_train)
test_r2=model.score(x_test,y_test)

print(train_r2,test_r2)
# Out:
# 0.9055159502227753 0.8609466508230368

# %% [markdown]
# # Checklist

# %% [markdown]
# * 1. Check wheather model has overfitting or underfitting problem.
#
# * 2. Is Test Accuracy = Cross Validation Score
#
# * 3. Check Assumptions(if it is linnear Regression)
#
# * 4. Check model meets the business problem requirements.
#
# * 5. Finally, save the model and share to the deployment team.

# %% [markdown]
# # 1 .Is model has underfiting or overfiting problem?
#
# ----> It's a good model

# %% [markdown]
# # 2.Test Accuracy = Cross validation Score.

# %%
from sklearn.model_selection import cross_val_score

scores= cross_val_score(model,x,y,cv=5)

scores.mean()
# Out:
# 0.8871063495438435

# %% [markdown]
# # Check for Assumptions

# %% [markdown]
# # 1. linearity of Error

# %%
test_res = y_test-test_predictions #Residual(error)
test_res
# Out:
# 95      334.603703
# 15     1211.772084
# 30     -151.070583
# 158   -3589.238156
# 128    2497.680117
# 115    -755.568716
# 69     1103.074982
# 170    1049.714775
# 174   -1775.470791
# 45     -224.495113
# 66      485.569739
# 182    2174.571754
# 165   -2402.059915
# 78    -3670.260418
# 186     843.204241
# 177    -304.543506
# 56    -3415.494028
# 152     443.807491
# 82     1004.171167
# 68      175.264469
# 124     -68.218177
# 16    -1274.690281
# 148   -1596.389075
# 93      664.982383
# 65     1691.392593
# 60     2488.019905
# 84      782.405171
# 67     1593.723352
# 125    1519.233632
# 132   -2814.120118
# 9     -1576.048907
# 18     1330.806103
# 55     1969.910445
# 75    -4077.705784
# 150   -2001.136196
# 104     624.092043
# 135   -2662.025561
# 137    -138.265349
# 164    1060.611733
# 76     2518.093925
# 79     1486.675944
# 197     395.136763
# 38      -70.454342
# 24     1609.186367
# 122   -1563.884274
# 195    2375.644796
# 29     1211.061671
# ...

# %%
plt.scatter(test_predictions,test_res)
plt.xlabel("Observed_value")
plt.ylabel("Fitted_value")
plt.show()

# %% [markdown]
# # 2. Normality of Errors

# %%
sns.displot(test_res,kde=True,bins=15)
plt.show()

# %% [markdown]
# # 3. Equal Variance of Error

# %%
plt.scatter(test_predictions,test_res,c='r')
plt.axhline(y=0,color='blue')
plt.xlabel("fitted_values")
plt.ylabel("Observed_values")
plt.show()

# %% [markdown]
# # 4. Variable Significance

# %% [markdown]
# Hypothesis Testing for Variables.
#
# * Null hypothesis:  There is no relationship between input and output
#       variable (and thus B1 zero).
#
# * Alternative hypothesis : There is a relationship between input and output variable( and thus B1 not equal to zero)

# %%
import statsmodels.formula.api as smf

model1=smf.ols("y~x",data=df).fit()

model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):           1.58e-96
# Time:                        13:02:19   Log-Likelihood:                -1767.7
# No. Observations:                 200   AIC:                             3543.
# Df Residuals:                     196   BIC:                             3557.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2938.8894    311.908      9.422      0.000    2323.762    3554.016
# ...

# %% [markdown]
# # Checking wheather data has any  influential values by using Influence index plots

# %%
import statsmodels.api as sm
sm.graphics.influence_plot(model1)

# %%
df.iloc[130]
# Out:
# TV             700
# radio        39600
# newspaper     8700
# sales         1600
# Name: 130, dtype: int64

# %% [markdown]
# * index 130 is showing high influence so we can exclud       that entire row.
#
# * Studentized Residuals = Residual/standard deviation of     residuals

# %%
df_new=df.drop(df.index[[130]],axis=0)
df_new
# Out:
#          TV  radio  newspaper  sales
# 0    230100  37800      69200  22100
# 1     44500  39300      45100  10400
# 2     17200  45900      69300   9300
# 3    151500  41300      58500  18500
# 4    180800  10800      58400  12900
# ..      ...    ...        ...    ...
# 195   38200   3700      13800   7600
# 196   94200   4900       8100   9700
# 197  177000   9300       6400  12800
# 198  283600  42000      66200  25500
# 199  232100   8600       8700  13400
#
# [199 rows x 4 columns]

# %%
lm= smf.ols(formula='sales~TV+radio+newspaper', data=df_new).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.908
# Method:                 Least Squares   F-statistic:                     653.7
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):          1.88e-101
# Time:                        13:02:22   Log-Likelihood:                -1743.8
# No. Observations:                 199   AIC:                             3496.
# Df Residuals:                     195   BIC:                             3509.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   3093.0655    290.332     10.654      0.000    2520.471    3665.660
# ...

# %% [markdown]
# Varaiance inflation Factor(VIF)
#
# * VIF measures the ratio between the variance for a given regression coefficient with only that variable in the model
# versus the variance for a given regression coefficient with all variables in the model.

# %%
rsq_TV=smf.ols('TV~radio+newspaper',data=df).fit()
rsq_TV.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                     TV   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.4542
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):              0.636
# Time:                        13:02:23   Log-Likelihood:                -2554.9
# No. Observations:                 200   AIC:                             5116.
# Df Residuals:                     197   BIC:                             5126.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.366e+05   1.26e+04     10.826      0.000    1.12e+05    1.61e+05
# ...

# %%
# Calculating VIF's values of independent variables

rsq_TV = smf.ols('TV~radio+newspaper',data=df).fit().rsquared

vif_TV=1/(1-rsq_TV)


rsq_radio = smf.ols('radio~TV+newspaper',data=df).fit().rsquared
vif_radio=1/(1-rsq_radio)

rsq_newspaper = smf.ols('newspaper~radio+TV',data=df).fit().rsquared
vif_newspaper= 1/(1-rsq_radio)

# %%
# Storing vif values in a data frame

d1={'Variables':['Tv','radio','newspaper'],'VIF':[vif_TV,vif_radio,vif_newspaper]}

Vif_frame = pd.DataFrame(d1)

Vif_frame
# Out:
#    Variables       VIF
# 0         Tv  1.004611
# 1      radio  1.144952
# 2  newspaper  1.144952

# %% [markdown]
# * if VIF > 4, for any independent variable, then drop that particular variable
#
# * If the VIF of model > 4 (threshold values=4)...then there exists a problem and reinvestigate the problem.

# %% [markdown]
# # Added variable plot(Av plot)

# %% [markdown]
# * partial differentiation insted of normal differentiation

# %%
sm.graphics.plot_partregress_grid(lm)
# Out:
# eval_env: 1
# eval_env: 1
# eval_env: 1
# eval_env: 1

# %% [markdown]
# # Final model including Tv and Radio only

# %%
final_model = smf.ols(formula='sales~TV+radio',data=df).fit()  #deleted newspaper
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):           4.83e-98
# Time:                        14:21:58   Log-Likelihood:                -1767.7
# No. Observations:                 200   AIC:                             3541.
# Df Residuals:                     197   BIC:                             3551.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2921.0999    294.490      9.919      0.000    2340.343    3501.857
# ...

# %%
#again do all steps.

x=df[["radio","TV"]]
y=df['sales']

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
#import model

model=LinearRegression()  #save the model

model.fit(x_train,y_train) #Fit the data
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 2837.617236905173

# %%
model.coef_
# Out:
# array([0.20260566, 0.04407736])

# %%
train_predictions=model.predict(x_train)
train_predictions
# Out:
# array([17516.43182895, 15242.2407001 , 11339.29011384, 10998.11714892,
#        16481.59017235,  6934.40865117, 21390.90809164,  6113.39242439,
#         9749.97496128, 11867.61847617,  9207.99891924,  6372.62183434,
#        14808.95506183, 17406.33970149, 15854.29073347, 16249.90932854,
#        15072.61838328, 19881.91030199, 13511.6273391 , 21190.1311896 ,
#        12895.34766843, 13923.20090081,  8797.15282166, 17075.58393519,
#         8353.59934556, 15081.30810715, 13868.32994573, 23475.99358879,
#        12905.76572146, 23006.29412465,  6640.86842806, 18547.64300019,
#        23256.73338246, 18596.6783201 , 17163.56312744, 16648.76011354,
#        12370.5502176 , 12017.53130089, 16804.10686037, 14495.58045211,
#        12994.94578085,  7425.84551254, 19283.18390611,  9406.62216722,
#        19545.06825706, 10076.42341945,  6926.24382606, 16525.71817775,
#        13702.13725773, 14899.61366134, 11244.57484966, 20638.31263463,
# ...

# %%
test_predictions=model.predict(x_test)
test_predictions
# Out:
# array([16437.78962684, 21114.62413059, 21481.61733249, 10829.47123087,
#        22475.53785294, 13239.02535914, 21287.97821544,  7391.71108966,
#        13329.28224557, 15114.19102154,  9210.15342772,  6469.61735594,
#        13862.61835067,  9133.54422101,  9411.88140786, 11919.90874343,
#         8852.60102567, 16268.01624042, 10269.53763773, 18873.2390997 ,
#        19497.5350891 , 13241.42965668, 12677.5651478 , 21291.73444972,
#         7763.18798998,  5600.96753294, 20960.17782052, 11915.3761125 ,
#         9071.91016451,  8718.74103261, 12171.04929029, 10041.18684887,
#        21613.32452589, 12436.39200838, 18026.35199459, 20286.21947535,
#        14489.01991605, 20756.89533826, 10981.78749871,  4373.91380365,
#         9510.65504554, 12523.54330823, 10146.92273568,  8136.46832705,
#        13197.20036859,  5271.01348396,  9191.16969093, 14172.48822399,
#         8602.96177634, 11772.37574998, 15766.41196949, 11698.74552649,
# ...

# %%
from sklearn.metrics import mean_squared_error

train_rmse = np.sqrt(mean_squared_error(y_train,train_predictions))

test_rmse = np.sqrt(mean_squared_error(y_test,test_predictions))

print(train_rmse,test_rmse)
# Out:
# 1580.2375959959866 1915.4756731764248

# %%
train_R2=model.score(x_train,y_train)
train_R2
# Out:
# 0.9048377867980043

# %%
test_R2=model.score(x_test,y_test)
test_R2
# Out:
# 0.8656253548947075

# %%
#cross validation
from sklearn.model_selection import cross_val_score

scores=cross_val_score(model,x,y,cv=5)

scores.mean()
# Out:
# 0.889282957306453

# %%
#Line Assumption
#residual

test_res=y_test-test_predictions
test_res
# Out:
# 95      462.210373
# 15     1285.375869
# 30      -81.617332
# 158   -3529.471231
# 128    2224.462147
# 115    -639.025359
# 69     1012.021785
# 170    1008.288910
# 174   -1829.282246
# 45     -214.191022
# 66      289.846572
# 182    2230.382644
# 165   -1962.618351
# 78    -3833.544221
# 186     888.118592
# 177    -219.908743
# 56    -3352.601026
# 152     331.983760
# 82     1030.462362
# 68       26.760900
# 124     202.464911
# 16     -741.429657
# 148   -1777.565148
# 93      908.265550
# 65     1536.812010
# 60     2499.032467
# 84      739.822179
# 67     1484.623888
# 125    1528.089835
# 132   -3018.741033
# 9     -1571.049290
# 18     1258.813151
# 55     2086.675474
# 75    -3736.392008
# 150   -1926.351995
# 104     413.780525
# 135   -2889.019916
# 137      43.104662
# 164     918.212501
# 76     2526.086196
# 79     1489.344954
# 197     276.456692
# 38      -46.922736
# 24     1563.531673
# 122   -1597.200369
# 195    2328.986516
# 29     1308.830309
# ...

# %%
#Linearity of error

plt.scatter(test_predictions,test_res)
plt.xlabel("Observed_value")
plt.ylabel("Fitted_value")
plt.show()

# %%
#Normality of error

sns.displot(test_res,kde=True)
plt.show()

# %%
#Equality of variance

plt.scatter(test_predictions,test_res,c='r')
plt.axhline(y=0,color='blue')
plt.xlabel("fitted_values")
plt.ylabel("Observed_values")
plt.show()

# %%
#Variable significance

import statsmodels.formula.api as smf

model1=smf.ols("y~x",data=df).fit()

model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Tue, 17 Oct 2023   Prob (F-statistic):           4.83e-98
# Time:                        13:26:13   Log-Likelihood:                -1767.7
# No. Observations:                 200   AIC:                             3541.
# Df Residuals:                     197   BIC:                             3551.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2921.0999    294.490      9.919      0.000    2340.343    3501.857
# ...

# %%
model.predict([[20000,40000]])  #model
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([8652.82498864])

# %%
#save model

from joblib import dump

dump(model,'mul_model')
# Out:
# ['mul_model']

# %%
#load model

from joblib import load

loded_model=load('mul_model')

# %%
loded_model.predict([[2220000,3330000]])
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([599399.8035758])
